# %% [markdown]
# # 🧪 LAB 1 — Pose Estimation with MediaPipe
#
# ## Objective
# Implement real-time pose estimation and analyze its limitations.
#
# ## Instructions
# Use ChatGPT to help generate code, but you must:
# - Understand and explain it
# - Modify it as requested
# - Answer conceptual questions

# %% [markdown]
# ## Install dependencies

# %%
# !pip install mediapipe opencv-python

# %% [markdown]
# ## Base Implementation

# %%
import cv2
import mediapipe as mp

mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_draw = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb)

    if results.pose_landmarks:
        mp_draw.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

    cv2.imshow('Pose', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Modification Task
# - Compute an angle (e.g., elbow)
# - Display it on screen
# - Detect a condition (e.g., arm raised)

# %% [markdown]
# ## Questions
# 1. What happens with multiple people?
# 2. Why is MediaPipe fast?
# 3. When would it fail in production?
