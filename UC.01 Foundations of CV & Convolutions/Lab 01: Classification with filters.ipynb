# %% [markdown]
# # **Lab 01:** Classification with filters

# %% [markdown]
# In this activity, you will simulate how convolutional neural networks (CNNs) extract features from images — but **manually**, using your own designed filters (kernels).
#
# ---
#
# ### **General Instructions**
#
# - Select a dataset with **2 classes**
# - Each class must contain **at least 10 images**
# - Display **at least 10 random images per class**
# - Implement **image filters manually** (**maximum 2 filters**)
# - Visualize the **feature maps** obtained after applying each filter
# - Justify the **kernel values** you selected
# - Create an **image classifier** using the filter outputs
# - Your classifier must achieve **at least 70% accuracy**
# - Explain clearly **how your classifier works**
#
# ---
#
# ### **System Diagram Requirement**
#
# You must include a **diagram of your system pipeline** showing:
#
# - Order of filtering
# - Whether filters are applied **in cascade (sequentially)** or **in parallel**, etc.
# - How feature maps are combined (**fusion, thresholding, voting, etc.**)
# - What the **activation maps look like** after each step
#
# You may draw it digitally or by hand and include an image.
#
# This diagram is **required** to understand your model logic.

# %% [markdown]
# ### **Dataset Selection and Visualization**

# %%
# Load your dataset here
# It must contain 2 classes with at least 10 images per class

# %%
# Display at least 10 random images per class

# %% [markdown]
# ### **Manual Filter Design**

# %%
# Define Kernel 1 and Kernel 2 (max 2 filters)

kernel1 = None  # Replace with your 3x3 kernel
kernel2 = None  # Replace with your 3x3 kernel (optional)

# %%
# Apply convolution manually and visualize feature maps

# %% [markdown]
# ### **Build Your Classifier**

# %%
# Use the feature maps to build a classifier
# You can use thresholds, rules, or a simple ML model

# %%
# Evaluate accuracy (must be >= 70%)

# %% [markdown]
# ### **Written Analysis Questions**

# %% [markdown]
# Answer the following questions:
#
# **1. What values did you put in your Kernel 1 and why?**
#
# ```
# My Kernel 1:
# [ ?,  ?,  ? ]
# [ ?,  ?,  ? ]
# [ ?,  ?,  ? ]
#
# Reason:
# [Your answer here]
# ```
#
# ---
#
# **2. What values did you put in your Kernel 2 and why?**
#
# ```
# My Kernel 2:
# [ ?,  ?,  ? ]
# [ ?,  ?,  ? ]
# [ ?,  ?,  ? ]
#
# Reason:
# [Your answer here]
# ```
#
# ---
#
# **3. How does your classifier work?**
#
# ```
# [Explain in 3–4 lines how you combine the kernels to classify]
# ```
#
# ---
#
# **4. What patterns does each kernel detect?**
#
# ```
# Kernel 1 detects:
# [Your answer here]
#
# Kernel 2 detects:
# [Your answer here]
# ```
#
# ---
#
# **5. If your classifier was not 100% accurate, what would you change?**
#
# ```
# [Your answer here]
# ```
#
# ---
#
# **6. Connection to CNNs: How does this relate to convolutional neural networks?**
#
# ```
# [In 3–4 lines, explain how this exercise helps you understand convolution layers in CNNs]
# ```

# %% [markdown]
# ### **System Diagram**
#
# Insert your system diagram below (image or drawing). It must clearly show:
#
# - Filter order
# - Feature map outputs
# - Whether filters are cascaded or parallel
# - How outputs are fused into the final classifier

# %%
# Insert or display your system diagram image here

# %% [markdown]
# ### **Grading Rubric (10 points)**
#
# | Criterion | Points |
# |----------|--------|
# | Dataset selection and visualization (2 classes, ≥10 images each) | 1 |
# | Correct manual implementation of filters | 2 |
# | Feature map visualization after each filter | 2 |
# | Kernel justification and written explanations | 1 |
# | System didagram (classifier design clarity) | 2 |
# | Accuracy ≥ 70% | 1 |
# | CNN conceptual connection | 1 |
# | **Total** | **10** |

# %% [markdown]
# ---
#
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
