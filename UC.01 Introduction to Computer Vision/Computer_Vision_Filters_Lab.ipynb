# %% [markdown]
# # Lab: Building a Simple Image Classifier Using Filters
# In this lab you will act like a tiny Convolutional Neural Network by manually designing filters to distinguish between two images.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (6,6)
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# ## Load Images

# %%
imgA = cv2.imread('imageA.jpg', cv2.IMREAD_GRAYSCALE)
imgB = cv2.imread('imageB.jpg', cv2.IMREAD_GRAYSCALE)

plt.imshow(imgA)
plt.title('Image A')
plt.show()

plt.imshow(imgB)
plt.title('Image B')
plt.show()

# %% [markdown]
# ## Convolution Function

# %%
def convolve2d(image, kernel):
    h, w = image.shape
    kh, kw = kernel.shape
    pad = kh // 2
    padded = np.pad(image, pad, mode='constant')
    output = np.zeros_like(image, dtype=float)

    for i in range(h):
        for j in range(w):
            region = padded[i:i+kh, j:j+kw]
            output[i,j] = np.sum(region * kernel)

    return output

# %% [markdown]
# ## TODO 1: Define Your Own Filters

# %%
# Students design kernels here
my_kernel = np.array([[0,0,0],[0,1,0],[0,0,0]])

# %% [markdown]
# ## TODO 2: Extract Features

# %%
def feature_score(filtered_img):
    return np.mean(np.abs(filtered_img))

featA = feature_score(convolve2d(imgA, my_kernel))
featB = feature_score(convolve2d(imgB, my_kernel))

print('Feature score A:', featA)
print('Feature score B:', featB)

# %% [markdown]
# ## TODO 3: Simple Classifier

# %%
if featA > featB:
    print('Kernel responds more to Image A')
else:
    print('Kernel responds more to Image B')

# %% [markdown]
# ---
# # 🔒 Instructor Section — Secret Kernels
# Use these to verify results after students experiment.
#
# Vertical Edge Kernel:
# ```
# [[-1,0,1],[-2,0,2],[-1,0,1]]
# ```
#
# Horizontal Edge Kernel:
# ```
# [[-1,-2,-1],[0,0,0],[1,2,1]]
# ```
#
# Sharpen Kernel:
# ```
# [[0,-1,0],[-1,5,-1],[0,-1,0]]
# ```
