# %% [markdown]
# # **Tutorial:** Real-time Object Detection with YOLO

# %% [markdown]
# In this tutorial, you will learn how to use the YOLOv26 model with OpenCV to automatically detect and draw bounding boxes around objects in an image.

# %% [markdown]
# ### **Step 1: Install Required Packages**

# %% [markdown]
# Install the necessary packages including OpenCV and other dependencies:

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall

# %% [markdown]
# Verify the installations:

# %%
# %pip show opencv-python ultralytics

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %% [markdown]
# Import the libraries you will use:

# %%
import numpy as np
import math
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the YOLOv26 Model**

# %% [markdown]
# Load the pre-trained YOLOv26 model (automatically downloads if not available):

# %%
# Load a pretrained YOLO model version 26, nano (n) size
model = YOLO('yolo26n.pt')  # Using nano version for speed, other options: yolov26s.pt (small), yolov26m.pt (medium), yolov26l.pt (large), yolov26x.pt (extra large)

# %%
# Show class names the model can detect 
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### **Step 4.1: Run YOLO on an Image**

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Define path to the image file
source = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/cat.jpg"

# Run inference on the source
results = model(source, show=True) # list of Results objects

# %% [markdown]
# ### **Step 4.2: Run YOLO on an Image + save result in working directory + plot with matplotlib**

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Cargar modelo
model = YOLO("yolo26n.pt")

# Ruta de la imagen
source = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/cat.jpg"

# Inferencia + guardar resultado
results = model(
    source, 
    save=True,
    project="/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection",  # carpeta base
    name="yolo_results", # subcarpeta
    exist_ok=True  # sobreescribe si ya existe
    )

# Mostrar con matplotlib
for r in results:
    img = r.plot()  # imagen con bounding boxes
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convertir BGR a RGB

    plt.figure(figsize=(8, 6))
    plt.imshow(img)
    plt.axis("off")
    plt.title("YOLO Detection Result")
    plt.show()

# (Opcional) imprimir info de detecciones
for r in results:
    print(r.boxes)
# Out:
# image 1/1 /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/cat.jpg: 640x640 1 cat, 294.5ms
# Speed: 9.0ms preprocess, 294.5ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/yolo_results
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([15.])
# conf: tensor([0.8558])
# data: tensor([[2.0359e+02, 1.2762e+02, 7.8516e+02, 9.5925e+02, 8.5582e-01, 1.5000e+01]])
# id: None
# is_track: False
# orig_shape: (960, 940)
# shape: torch.Size([1, 6])
# xywh: tensor([[494.3746, 543.4372, 581.5696, 831.6308]])
# xywhn: tensor([[0.5259, 0.5661, 0.6187, 0.8663]])
# xyxy: tensor([[203.5898, 127.6218, 785.1594, 959.2526]])
# xyxyn: tensor([[0.2166, 0.1329, 0.8353, 0.9992]])

# %% [markdown]
# ### **Step 5.1: Run YOLO on a saved video**

# %% [markdown]
# #### Option 1: Save the processed video on the working directory

# %%
from ultralytics import YOLO
import cv2
import os

model = YOLO("yolo26n.pt")

source = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4"
output_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/yolo_results/classroom-results.avi"

os.makedirs(os.path.dirname(output_path), exist_ok=True)

results = model(source, stream=True)

out = None

for r in results:
    frame = r.plot()

    if out is None:
        h, w = frame.shape[:2]
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")  # 🔥 estable en Mac
        out = cv2.VideoWriter(output_path, fourcc, 20, (w, h))

        print("Writer abierto:", out.isOpened())

    out.write(frame)

if out:
    out.release()
    print("Video guardado")
else:
    print("Nada se guardó")
# Out:
# video 1/1 (frame 1/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 1 bottle, 9 chairs, 1 dining table, 157.7ms
# Writer abierto: True
# video 1/1 (frame 2/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 58.9ms
# video 1/1 (frame 3/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 42.3ms
# [ WARN:0@504.583] global cap.cpp:781 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.13.0) /Users/macmini_16g/GHA-Actions-Opencv-Python/_work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:411: error: (-215:Assertion failed) !filename_pattern.empty() in function 'CvVideoWriter_Images'
# video 1/1 (frame 4/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 45.7ms
# video 1/1 (frame 5/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 47.4ms
# video 1/1 (frame 6/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 45.2ms
# video 1/1 (frame 7/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 44.5ms
# video 1/1 (frame 8/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 52.1ms
# video 1/1 (frame 9/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 51.5ms
# video 1/1 (frame 10/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 52.7ms
# video 1/1 (frame 11/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 50.3ms
# video 1/1 (frame 12/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 48.3ms
# video 1/1 (frame 13/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 45.3ms
# video 1/1 (frame 14/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 40.2ms
# video 1/1 (frame 15/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 41.6ms
# video 1/1 (frame 16/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 44.3ms
# video 1/1 (frame 17/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 39.6ms
# video 1/1 (frame 18/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 42.5ms
# video 1/1 (frame 19/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 49.6ms
# video 1/1 (frame 20/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 50.2ms
# video 1/1 (frame 21/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 12 chairs, 1 dining table, 38.3ms
# video 1/1 (frame 22/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 39.5ms
# video 1/1 (frame 23/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 42.3ms
# video 1/1 (frame 24/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 44.1ms
# video 1/1 (frame 25/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 39.6ms
# video 1/1 (frame 26/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 38.8ms
# video 1/1 (frame 27/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 37.2ms
# video 1/1 (frame 28/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 12 chairs, 1 dining table, 44.8ms
# video 1/1 (frame 29/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 12 chairs, 1 dining table, 37.7ms
# video 1/1 (frame 30/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 12 chairs, 1 dining table, 1 tv, 36.3ms
# video 1/1 (frame 31/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 69.2ms
# video 1/1 (frame 32/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 43.5ms
# video 1/1 (frame 33/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 39.3ms
# video 1/1 (frame 34/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 12 chairs, 1 dining table, 1 tv, 39.2ms
# video 1/1 (frame 35/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 40.2ms
# video 1/1 (frame 36/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 47.2ms
# video 1/1 (frame 37/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 42.7ms
# video 1/1 (frame 38/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 47.5ms
# video 1/1 (frame 39/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 46.1ms
# video 1/1 (frame 40/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 46.5ms
# video 1/1 (frame 41/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 47.5ms
# video 1/1 (frame 42/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 43.6ms
# video 1/1 (frame 43/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 43.5ms
# video 1/1 (frame 44/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 42.4ms
# video 1/1 (frame 45/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 46.2ms
# video 1/1 (frame 46/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 42.9ms
# video 1/1 (frame 47/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 41.3ms
# video 1/1 (frame 48/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 46.8ms
# video 1/1 (frame 49/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 41.9ms
# video 1/1 (frame 50/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 36.9ms
# video 1/1 (frame 51/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 36.7ms
# video 1/1 (frame 52/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 1 tv, 37.7ms
# video 1/1 (frame 53/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 11 chairs, 1 dining table, 1 tv, 42.4ms
# video 1/1 (frame 54/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table, 137.0ms
# video 1/1 (frame 55/984) /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/classroom.mp4: 384x640 4 persons, 10 chairs, 1 dining table,
ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Video guardado

# %% [markdown]
# #### Option 2: Show the video on real-time

# %%
from ultralytics import YOLO
import cv2

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Configure your video path
#video_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/fruit-and-vegetable-detection.mp4"
#video_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/car-detection.mp4"
video_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/worker-zone-detection.mp4"

# Open video
cap = cv2.VideoCapture(video_path)

# Verify video opened correctly
if not cap.isOpened():
    print("Error: Could not open video. Check the path.")
else:
    print("Video loaded successfully. Press 'q' to exit.")
    
    # Process each video frame
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break  # Finish when video ends
            
        # Run detection with YOLO
        results = model(frame)
        
        # Draw bounding boxes
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                confidence = float(box.conf[0].cpu().numpy())
                class_id = int(box.cls[0].cpu().numpy())
                
                # Only show detections with confidence > 50%
                if confidence > 0.5:
                    # Draw rectangle
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Show label
                    label = f"{model.names[class_id]}: {confidence:.2f}"
                    cv2.putText(frame, label, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Show frame with detections
        cv2.imshow('Object Detection', frame)
        
        # Exit with 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Processing completed.")
# Out:
# Video loaded successfully. Press 'q' to exit.
#
# 0: 384x640 1 person, 75.0ms
# Speed: 3.9ms preprocess, 75.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.9ms
# Speed: 1.4ms preprocess, 71.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.5ms
# Speed: 1.2ms preprocess, 47.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.1ms
# Speed: 1.9ms preprocess, 113.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.5ms
# Speed: 1.7ms preprocess, 54.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.1ms
# Speed: 1.1ms preprocess, 93.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.3ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.9ms
# Speed: 1.8ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 150.4ms
# Speed: 2.5ms preprocess, 150.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.2ms
# Speed: 1.1ms preprocess, 40.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.8ms
# Speed: 1.3ms preprocess, 36.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.1ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.8ms
# Speed: 1.2ms preprocess, 36.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.7ms
# Speed: 1.3ms preprocess, 65.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.7ms
# Speed: 1.1ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.6ms
# Speed: 1.2ms preprocess, 40.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.8ms
# Speed: 1.1ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.7ms
# Speed: 1.2ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.4ms
# Speed: 1.1ms preprocess, 36.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.2ms
# Speed: 1.1ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.2ms
# Speed: 1.2ms preprocess, 36.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.2ms
# Speed: 1.1ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.2ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.8ms
# Speed: 1.2ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.1ms preprocess, 37.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.6ms
# Speed: 1.2ms preprocess, 54.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.0ms
# Speed: 1.2ms preprocess, 99.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.5ms
# Speed: 1.6ms preprocess, 50.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58
ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.4ms
# ...
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.5ms
# Speed: 1.3ms preprocess, 44.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.8ms
# Speed: 1.2ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 apple, 73.6ms
# Speed: 1.2ms preprocess, 73.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 apple, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 apple, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 apple, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.1ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.5ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 87.1ms
# Speed: 1.3ms preprocess, 87.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.2ms
# Speed: 1.5ms preprocess, 67.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 63.4ms
# Speed: 1.5ms preprocess, 63.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.9ms
# Speed: 1.3ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 81.0ms
# Speed: 1.2ms preprocess, 81.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.1ms
# Speed: 1.4ms preprocess, 50.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.3ms
# Speed: 1.2ms preprocess, 47.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.9ms
# Speed: 1.3ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.1ms
# Speed: 1.3ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.1ms
# Speed: 1.4ms preprocess, 52.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.6ms
# Speed: 1.9ms preprocess, 82.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 1.3ms preprocess, 44.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.8ms
# Speed: 1.3ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.4ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.8ms
# Speed: 1.3ms preprocess, 51.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.2ms
# Speed: 1.4ms preprocess, 52.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.2: Run YOLO on your webcam video**

# %% [markdown]
# #### Option 1: Simple

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Run inference on the source
results = model(source=0, show=True)

# %% [markdown]
# #### Option 2: Optimized

# %%
from ultralytics import YOLO

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

#  Run YOLO model on your webcam
results = model.predict(
    source=0, # source=0 uses the default webcam, use source=1 for an external camera.
    show=True, # show=True to display the video feed with detections in a window
    imgsz=256, # resize frames to 256x256 for faster processing and lower resource usage
    vid_stride= 6, # process every 3rd frame to reduce CPU/GPU load
    save=False, # do not save the video output (this saves disk space and speeds up processing)
    verbose=False, # stops printing per-frame logs
    conf=0.3, # confidence threshold of 30% (default is 0.25). Adjust as needed.
)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### Option 3: Complete

# %%
from ultralytics import YOLO
import cv2
import math

# Load a pretrained YOLO26n model
model = YOLO("yolo26n.pt")

# Configure video capture from the camera
capture = cv2.VideoCapture(0)  # Open the default camera

# Define class names (YOLO COCO dataset classes)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Set the image width and height
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Image width
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Image height

# Start a loop to process camera frames
while True:
    success, img = capture.read()  # Capture a frame

    # Perform object detection on the captured image (using the pre-trained YOLO model we loaded earlier)
    results = model(img, stream=True)  # Stream generator to process detection results in real time

    # Process the detection results (we can have multiple objects detected in a single frame)
    for r in results:
        boxes = r.boxes

        # Iterate over the detected bounding boxes
        for box in boxes:
            # Get the bounding box coordinates in xyxy format
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Get the detection confidence (value between 0 and 1) and round to two decimal places
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Get the numeric identifier of the detected class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display the class name next to the bounding box
            org = [x1, y1]  # Coordinates of the top-left corner for the text
            font = cv2.FONT_HERSHEY_SIMPLEX # Font type
            fontScale = 1  # Font scale
            color = (255, 0, 0)  # Color: Blue (BGR format)
            thickness = 1  # Text line thickness
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the image with a window name and the processed image with detections
    cv2.imshow('YOLO Detection', img)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 199.1ms
# Speed: 3.2ms preprocess, 199.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 480x640 3 books, 60.8ms
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.1ms preprocess, 60.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 124.5ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 124.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 76.4ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 1.1ms preprocess, 76.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 54.4ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 89.3ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 89.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 65.5ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.0ms preprocess, 65.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 50.0ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.9ms preprocess, 50.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 42.6ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 43.1ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 46.5ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 40.8ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 53.3ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.0ms preprocess, 53.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 0.7ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 49.2ms
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 49.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 40.2ms
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 40.8ms
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 48.7ms
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 48.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 43.2ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 43.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 41.4ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 38.1ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 47.9ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 47.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 41.3ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.0ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.2ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 77.3ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 77.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.6ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.9ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 41.6ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.8ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 38.4ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.8ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.0ms
# Speed: 0.7ms preprocess, 36.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 38.7ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 43.6ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.0ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.4ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 38.3ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 39.4ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.2ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 36.7ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 36.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 37.2ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 42.9ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.0ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.1ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 40.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.3ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.0ms
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 38.0ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 38.0ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 39.2ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 42.2ms
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.7ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.2ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 36.1ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 books, 37.5ms
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 books, 38.7ms
# Confidence ---> 0.64
# Class name --> book
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 books, 39.0ms
# Confidence ---> 0.6
# Class name --> book
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 4 books, 39.8ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> book
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 3 books, 40.8ms
# Confidence ---> 0.96
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> book
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.8ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 41.8ms
# Confidence ---> 0.97
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Speed: 0.7ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 43.1ms
# Confidence ---> 0.96
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Speed: 0.6ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 38.1ms
# Confidence ---> 0.96
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Speed: 0.9ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 36.9ms
# Confidence ---> 0.92
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Speed: 0.6ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 37.2ms
# Confidence ---> 0.92
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Speed: 0.7ms preprocess, 37.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 38.9ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Speed: 0.9ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 39.2ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Speed: 0.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 42.8ms
# Confidence ---> 0.96
# Class name --> laptop
# Confidence ---> 0.51
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Speed: 0.6ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 39.3ms
# Confidence ---> 0.94
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Speed: 0.8ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 38.2ms
# Confidence ---> 0.94
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.8ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 40.9ms
# Confidence ---> 0.92
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Speed: 0.6ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 39.2ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Speed: 0.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 38.8ms
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Speed: 0.7ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 2 books, 39.3ms
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 0.9ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 2 books, 39.2ms
# Confidence ---> 0.8
# Class name --> tvmonitor
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 39.9ms
# Confidence ---> 0.84
# Class name --> tvmonitor
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Speed: 1.0ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 38.1ms
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.6ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 39.1ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.7ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 36.4ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.6ms preprocess, 36.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 38.3ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.55
# Class name --> tvmonitor
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.6ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 37.1ms
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 2 books, 36.9ms
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 2 books, 41.2ms
# Confidence ---> 0.7
# Class name --> tvmonitor
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.6ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 2 laptops, 2 books, 37.3ms
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 0.6ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 2 books, 37.3ms
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 0.6ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 3 books, 38.3ms
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 3 books, 36.1ms
# Confidence ---> 0.47
# Class name --> tvmonitor
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.8ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 4 books, 37.7ms
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 4 books, 38.2ms
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1 laptop, 4 books, 41.3ms
# Confidence ---> 0.49
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 3 books, 39.1ms
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 45.8ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Speed: 0.8ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 3 books, 39.1ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Speed: 1.1ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 38.8ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Speed: 0.8ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 38.1ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.7ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 36.7ms
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.6ms preprocess, 36.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 37.0ms
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Speed: 0.6ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 2 books, 37.9ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 37.9ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.45
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Speed: 0.6ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 40.4ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Speed: 0.6ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 43.9ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.43
# Class name --> book
# Speed: 0.6ms preprocess, 43.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 38.0ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Speed: 0.7ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 39.2ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.42
# Class name --> book
# Speed: 0.7ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 2 books, 37.2ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.6ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 2 books, 47.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.38
# Class name --> tvmonitor
# Speed: 0.6ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 2 books, 39.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> tvmonitor
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Speed: 1.0ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 39.0ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.4
# Class name --> book
# Speed: 0.7ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 2 books, 39.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 0.6ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 1 tv, 1 laptop, 2 books, 40.7ms
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.28
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> bed
# Speed: 0.6ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 2 books, 39.5ms
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 0.8ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 3 books, 37.4ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 3 books, 39.8ms
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 55.9ms
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Speed: 1.3ms preprocess, 55.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 37.4ms
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.8ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 38.0ms
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.6ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 37.3ms
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.6ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 39.5ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.7ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 2 books, 37.1ms
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.6ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 2 books, 46.5ms
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.7ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 2 books, 39.9ms
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.7ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 2 books, 39.2ms
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.9ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 3 books, 40.4ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.7ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 3 books, 37.0ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 3 books, 37.2ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 3 books, 39.8ms
# Confidence ---> 0.88
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 3 books, 37.9ms
# Confidence ---> 0.9
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 3 books, 41.5ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 41.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 3 books, 39.8ms
# Confidence ---> 0.9
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.7ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 4 books, 38.5ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 4 books, 39.1ms
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.29
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 3 books, 39.9ms
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ___

# %% [markdown]
# ### **Activity**

# %% [markdown]
# In this activity, the work will be developed **locally on your personal computers**.
#
# #### Objective
# Design a **specific object detection application** using YOLO (You Only Look Once), focused on **a limited subset of classes**. The system must show that **it only detects the activated classes**, visually ignoring objects belonging to deactivated classes (even if they are present in the image).
#
# #### Instructions
#
# 1. **Define a concrete application and the problem it solves**, for example: vehicle detection, fruits detection, etc.
# 2. **Select between 2 and 4 classes** from the YOLO model to detect.
# 3. **Modify the model logic** or post-processing so that **only the selected classes are shown**.
# 4. Run the application on video where **objects from non-activated classes** are also present to demonstrate that the system **ignores those classes**.
# 5. Show the results clearly, visually indicating the detected and non-detected objects.
#
# #### Deliverable
#
# Must be uploaded to the virtual classroom:
#
# - **Jupyter Notebook in PDF format** containing:
# - Commented code
# - Application title and the problem it solves
# - List of activated classes
# - Screenshots or test images with results showing:
#   - Objects *correctly detected* according to the activated classes. At least two objects should be detected at the same time.
#   - Objects *not detected* because they belong to deactivated classes (even if present in the image).
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Application Definition and Problem Statement** | 4 | Clearly defines a specific object detection application (using only the activated classes) and its practical use case. |
# | **2. Implementation** | 2 | Successfully modifies the model logic or post-processing to only show selected classes. Code is functional and properly ignores non-selected classes. The new code added should be commented/documented. |
# | **3. Testing & Evidence** | 4 | Provides a clear test showing both detected (activated classes) and ignored (deactivated classes) objects. Evidence demonstrates the |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
