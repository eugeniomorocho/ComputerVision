# %% [markdown]
# # **Tutorial:** Custom YOLO Object Detection with RoboFlow
#
# In this tutorial, you'll learn how to create a custom YOLO object detection model using your own classes and annotations with RoboFlow.

# %% [markdown]
# ### **Step 1: Install Required Dependencies**

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install roboflow
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %%
import cv2
from roboflow import Roboflow
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Image, display

# %% [markdown]
# ### **Step 3: Set Up RoboFlow Account**

# %% [markdown]
# 1. Go to RoboFlow and create a free account
# 2. Create a new project and select "Object Detection" as project type
# 3. Choose "YOLOv26" as the model format

# %% [markdown]
# ### **Step 4: Upload and Annotate Your Images**

# %% [markdown]
# #### Using RoboFlow Web Interface:
#
# 1. Click "Upload" to add your images
# 2. Use the annotation tool to draw bounding boxes around objects
# 3. Assign the correct class labels to each bounding box
# 4. Apply preprocessing and augmentation as needed

# %% [markdown]
# ### **Step 5. Download your Custom your Dataset**

# %% [markdown]
# 1. In RoboFlow, go to your project dashboard
# 2. Click "Generate" to create a dataset version
# 3. Apply any desired augmentations
# 4. Click "Export" and select "YOLOv**x**" format (**x** the version you are using)
# 5. Copy the download code

# %%
# Initialize RoboFlow (you'll need your API key)
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uugD71oI3JrBihabx7vV")
project = rf.workspace("eugenio-tblbg").project("test-fia")
version = project.version(2)
dataset = version.download("yolo26")
# Out:
# zsh:1: /Users/eugenio/Documents/ComputerVision/.venv/bin/pip: bad interpreter: /Users/eugenio/Documents/Computer_Vision/.venv/bin/python: no such file or directory
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in test-FIA-2 to yolo26:: 100%|██████████| 224/224 [00:00<00:00, 444.68it/s]
# Extracting Dataset Version Zip to test-FIA-2 in yolo26:: 100%|██████████| 21/21 [00:00<00:00, 2999.09it/s]

# %% [markdown]
# ### **Step 6: Train Your Custom YOLO Model**

# %%
OUTPUT_DIR = 'runs/detect/custom_yolo_model'

# Load the YOLO model with custom configuration
model = YOLO('yolo26n.pt')  # Using nano version as base

# Train the model on your custom dataset
results = model.train(
    data=f'{dataset.location}/data.yaml',  # Path to dataset config
    epochs=20,  # Number of training epochs
    imgsz=640,  # Image size
    batch=8,   # Batch size
    name='custom_yolo_model'  # Name for the training run
)
# Out:
# Ultralytics 8.4.150 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/test-FIA-2/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=custom_yolo_model, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241566  ultralytics.nn.modules.head.Detect           [1, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,190 parameters, 2,504,190 gradients, 5.9 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 111.7±30.1 MB/s, size: 25.8 KB)
# train: Scanning /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/test-FIA-2/train/labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6/6 3.1Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 152.4±0.0 MB/s, size: 33.4 KB)
# val: Scanning /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/test-FIA-2/valid/labels.cache... 1 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1/1 262.1Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model/labels.jpg...
# Using 6 train, 1 val images for fraction=1.0 at imgsz=640
# Using 0 dataloader workers
# Logging results to /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        1/20         0G      1.264      6.059    0.03217         14        640: 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.1it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        2/20         0G      1.505      6.409    0.03641         14        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.4it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        3/20         0G      1.201      6.094    0.02916         14        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.7it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        4/20         0G      1.428      8.561    0.05344          9        640: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.3it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        5/20         0G      1.196      6.666    0.03277         12        640: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.5it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        6/20         0G      1.072      4.841    0.02349         20        640: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.4it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        7/20         0G      1.023      5.101    0.02603         18        640: 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.7it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        8/20         0G       1.16      5.326    0.02782         17        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 12.0it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        9/20         0G       1.21       5.44    0.03298         16        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.7it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       10/20         0G      1.413      7.449    0.04991         10        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.5it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       11/20         0G      1.208       10.7     0.0402          6        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.7it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       12/20         0G      1.127      10.67    0.04034          6        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.2it/s 0.1s
#                    all          1          1    0.00333          1      0.249     0.0299
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       13/20         0G     0.9536      10.33      0.039          6        640: 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.4it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       14/20         0G      1.182      10.51     0.0515          6        640: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.9it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       15/20         0G     0.8926      10.16      0.041          6        640: 100% ━━━━━━━━━━━━ 1/1 1.8s/it 1.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.5it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       16/20         0G     0.8729      10.09    0.03639          6        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.1it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       17/20         0G     0.8118      9.962    0.03389          6        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.6it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       18/20         0G     0.8211      9.978    0.03211          6        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 13.6it/s 0.1s
#                    all          1          1    0.00333          1      0.199     0.0796
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       19/20         0G      1.377      10.95    0.06638          6        640: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.4it/s 0.1s
#                    all          1          1    0.00333          1      0.332      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       20/20         0G     0.8639      9.958    0.03013          6        640: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.1it/s 0.1s
#                    all          1          1    0.00333          1      0.332      0.133
#
# 20 epochs completed in 0.009 hours.
# Optimizer stripped from /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model/weights/last.pt, 5.4MB
# Optimizer stripped from /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model/weights/best.pt, 5.4MB
#
# Validating /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model/weights/best.pt...
# Ultralytics 8.4.150 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M4 Pro)
# YOLO26n summary (fused): 120 layers, 2,375,031 parameters, 0 gradients, 5.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 21.2it/s 0.0s
#                    all          1          1    0.00333          1      0.995      0.299
# Speed: 0.2ms preprocess, 42.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/runs/detect/custom_yolo_model

# %% [markdown]
# ### **Step 7: Evaluate Your Model**

# %%
# Evaluate model performance
metrics = model.val()  # Validate the model
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")

# Show some validation results
# !yolo task=detect mode=val model=runs/detect/custom_yolo_model/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.4.150 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M4 Pro)
# YOLO26n summary (fused): 120 layers, 2,375,031 parameters, 0 gradients, 5.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 150.7±0.0 MB/s, size: 33.4 KB)
# val: Scanning /Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/test-FIA-2/valid/labels.cache... 1 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1/1 67.7Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 19.5it/s 0.1s
#                    all          1          1    0.00333          1      0.995      0.299
# Speed: 0.4ms preprocess, 40.6ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /Users/eugenio/Documents/Notebooks_ArtificialIntelligence/runs/detect/val-3
# mAP50-95: 0.29850000000000004
# mAP50: 0.995

# %% [markdown]
# ### **Step 8: Test Your Custom Model on an Image**

# %%
# Load your custom trained model
custom_model = YOLO('/Users/eugenio/Documents/ComputerVision/runs/detect/custom_yolo_model/weights/best.pt')

# Test on a sample image
results = custom_model('/Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/taza_test.jpg', conf=0.25)

# Display results
# %matplotlib inline
for result in results:
    img = result.plot()  # Plot detections
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Load your custom trained model
# ----> 2 custom_model = YOLO('/Users/eugenio/Documents/ComputerVision/runs/detect/custom_yolo_model/weights/best.pt')
#       4 # Test on a sample image
#       5 results = custom_model('/Users/eugenio/Documents/ComputerVision/UC.04 Object Detection/taza_test.jpg', conf=0.25)
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/models/yolo/model.py:83, in YOLO.__init__(self, model, task, verbose)
#      80     self.__dict__ = new_instance.__dict__
#      81 else:
#      82     # Continue with default YOLO initialization
# ---> 83     super().__init__(model=model, task=task, verbose=verbose)
#      84     head = self.model.model[-1]._get_name() if hasattr(self.model, "model") else ""
#      85     if not head and isinstance(self.model, (str, Path)):  # an exported model keeps its head name in metadata
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/engine/model.py:133, in Model.__init__(self, model, task, verbose)
#     131     self._new(model, task=task, verbose=verbose)
#     132 else:
# --> 133     self._load(model, task=task)
#     135 # Delete super().training for accessing self.model.training
#     136 del self.training
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/engine/model.py:250, in Model._load(self, weights, task)
#     247 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo26n -> yolo26n.pt
#     249 if str(weights).rpartition(".")[-1] == "pt":
# --> 250     self.model, self.ckpt = load_checkpoint(weights)
#     251     self.task = self.model.task
#     252     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:1962, in load_checkpoint(weight, device, inplace, fuse)
#    1960 if str(weight).lower().startswith(REMOTE_FILE_PREFIXES):
#    1961     weight = check_file(weight, download_dir=SETTINGS["weights_dir"])
# -> 1962 ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1963 args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1964 candidate = ckpt.get("ema") or ckpt.get("model")
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:1861, in torch_safe_load(weight, safe_only)
#    1855 torchscript_error = emojis(
#    1856     f"ERROR ❌️ {weight} is a TorchScript archive, not an Ultralytics PyTorch checkpoint.\n"
#    1857     f"Load the original .pt weights, or export again with format='torchscript' and load that file directly."
#    1858 )
#    1860 try:
# -> 1861     ckpt = _load()
#    1863 except (RuntimeError, EOFError, pickle.UnpicklingError) as e:
#    1864     # An unreadable file reaches the loader as one of three internal errors depending on how it is damaged:
#    1865     # RuntimeError for a truncated zip, EOFError for an empty one, UnpicklingError for bytes that are not a
#    1866     # pickle at all (an image or archive renamed .pt). They are one user-facing condition, so they share one
#    1867     # handler and one message.
#    1868     if isinstance(e, RuntimeError) and "TorchScript archive" in str(e):
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/nn/tasks.py:1852, in torch_safe_load.<locals>._load()
#    1850     with _SafeLoad.loading(file):  # weights_only load against the known-class allow-list
#    1851         return torch_load(file, map_location="cpu", weights_only=True)
# -> 1852 return torch_load(file, map_location="cpu")
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/ultralytics/utils/patches.py:201, in torch_load(*args, **kwargs)
#     198 if TORCH_1_13 and "weights_only" not in kwargs:
#     199     kwargs["weights_only"] = False
# --> 201 return torch.load(*args, **kwargs)
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/Documents/ComputerVision/.venv/lib/python3.9/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/eugenio/Documents/ComputerVision/runs/detect/custom_yolo_model/weights/best.pt'

# %% [markdown]
# ### **Step 9: Test Your Custom Model on Video**

# %%
# Write your code here..

# %% [markdown]
# ## **Activity: Create Your Custom Detector**
#
# 1. **Create a RoboFlow account** and set up a new project
# 2. **Upload at least 25 images** of your custom objects (at least 2)
# 3. **Annotate all images** with bounding boxes and class labels
# 4. **Train a YOLO model** on your custom dataset
# 5. **Test your model** on new images and evaluate its performance
# 6. **Implement real-time detection** with your custom classes
#
# ## **Grading Rubric:**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Dataset Creation** | 4 | Successfully creates and annotates a custom dataset with at least 25 images and multiple classes in RoboFlow. |
# | **2. Model Training** | 1 | Properly trains a YOLOv8 model on the custom dataset with appropriate hyperparameters. |
# | **3. Model Evaluation** | 1 | Evaluates model performance with appropriate metrics and provides analysis of results. |
# | **4. Custom Detection** | 3 | Implements real-time detection with custom classes and displays results correctly. You have to use video from your webcam, no images or saved videos allowed. |
# | **5. Documentation** | 1 | Provides clear documentation of the process, including dataset details and model performance. |
#
# **Total: 10 points**
#
# ## **Tips for Success:**
#
# - **Quality over quantity**: Well-annotated images are more important than many poorly annotated ones
# - **Class balance**: Try to have a similar number of examples for each class
# - **Variety**: Include different angles, lighting conditions, and backgrounds
# - **Augmentation**: Use RoboFlow's augmentation features to expand your dataset

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
