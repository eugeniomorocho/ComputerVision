# %% [markdown]
# # **Tutorial:** Real-time Object Detection with YOLO

# %% [markdown]
# In this tutorial, you will learn how to use the YOLOv11 model with OpenCV to automatically detect and draw bounding boxes around objects in an image.

# %% [markdown]
# ### **Step 1: Install Required Packages**

# %% [markdown]
# Install the necessary packages including OpenCV and other dependencies:

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy==1.26.4 --force-reinstall
# Out:
# Requirement already satisfied: ultralytics in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (8.3.249)
# Collecting ultralytics
#   Downloading ultralytics-8.4.11-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: psutil>=5.8.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.4.11-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.4 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.249
#     Uninstalling ultralytics-8.3.249:
#       Successfully uninstalled ultralytics-8.3.249
# Successfully installed ultralytics-8.4.11
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Verify the installations:

# %%
# %pip show opencv-python ultralytics
# Out:
# Name: opencv-python
# Version: 4.11.0.86
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages
# Requires: numpy
# Required-by: ultralytics
# ---
# Name: ultralytics
# Version: 8.4.11
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /Users/eugenio/Documents/Computer_Vision/.venv/lib/python3.11/site-packages
# Requires: matplotlib, numpy, opencv-python, pillow, polars, psutil, pyyaml, requests, scipy, torch, torchvision, ultralytics-thop
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %% [markdown]
# Import the libraries you will use:

# %%
import numpy as np
import math
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the YOLOv11 Model**

# %% [markdown]
# Load the pre-trained YOLOv11 model (automatically downloads if not available):

# %%
# Load a pretrained YOLO model version 11, nano (n) size
model = YOLO('yolo11n.pt')  # Using nano version for speed, other options: yolov11s.pt (small), yolov11m.pt (medium), yolov11l.pt (large), yolov11x.pt (extra large)

# %%
# Show class names the model can detect 
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### **Step 4.1: Run YOLO on your webcam video (the simple way)**

# %%
# Run YOLO model on your webcam
results = model.predict(
    source=0, # source=0 uses the default webcam, use source=1 for an external camera
    show=True, # show=True to display the video feed with detections in a window 
    stream=True, # stream=True for real-time processing of video frames
    imgsz=256, # resize frames to 256x256 for faster processing and lower resource usage
    vid_stride=3, # process every 3rd frame to reduce CPU/GPU load
    save=False # do not save the video output (this saves disk space and speeds up processing)
    #verbose=False # stops printing per-frame logs
    #conf=0.3, # confidence threshold of 30% (default is 0.25). Adjust as needed.
)

# %% [markdown]
# ### **Step 4.2: Run YOLO on your webcam video (the complete way)**

# %%
# Configure video capture from the camera
capture = cv2.VideoCapture(0)  # Open the default camera

# Define class names (YOLO COCO dataset classes)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Set the image width and height
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Image width
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Image height

# Start a loop to process camera frames
while True:
    success, img = capture.read()  # Capture a frame

    # Perform object detection on the captured image (using the pre-trained YOLO model we loaded earlier)
    results = model(img, stream=True)  # Stream generator to process detection results in real time

    # Process the detection results (we can have multiple objects detected in a single frame)
    for r in results:
        boxes = r.boxes

        # Iterate over the detected bounding boxes
        for box in boxes:
            # Get the bounding box coordinates in xyxy format
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Get the detection confidence (value between 0 and 1) and round to two decimal places
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Get the numeric identifier of the detected class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display the class name next to the bounding box
            org = [x1, y1]  # Coordinates of the top-left corner for the text
            font = cv2.FONT_HERSHEY_SIMPLEX # Font type
            fontScale = 1  # Font scale
            color = (255, 0, 0)  # Color: Blue (BGR format)
            thickness = 1  # Text line thickness
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the image with a window name and the processed image with detections
    cv2.imshow('YOLO Detection', img)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 282.2ms
# Speed: 7.5ms preprocess, 282.2ms inference, 16.2ms postprocess per image at shape (1, 3, 480, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 480x640 1 book, 59.3ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.1ms preprocess, 59.3ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 book, 68.0ms
# Confidence ---> 0.35
# Class name --> suitcase
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.1ms preprocess, 68.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 50.3ms
# Confidence ---> 0.28
# Class name --> suitcase
# Speed: 1.0ms preprocess, 50.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 53.3ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.9ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 125.7ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.2ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 134.1ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 3.9ms preprocess, 134.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 130.2ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.0ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 100.5ms
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.6ms preprocess, 100.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 47.1ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 74.5ms
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 74.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 44.4ms
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 1.2ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 40.8ms
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.9ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 46.1ms
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 40.4ms
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.7ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 45.3ms
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.7ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 47.5ms
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Speed: 1.9ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 3 books, 47.2ms
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.26
# Class name --> cup
# Speed: 0.8ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 66.8ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 66.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 42.3ms
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 37.6ms
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.7ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 40.3ms
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.7ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 40.9ms
# Confidence ---> 0.44
# Class name --> book
# Speed: 0.6ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 36.9ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 47.0ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 book, 47.3ms
# Confidence ---> 0.35
# Class name --> suitcase
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.8ms preprocess, 47.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 suitcases, 1 book, 38.9ms
# Confidence ---> 0.39
# Class name --> suitcase
# Confidence ---> 0.32
# Class name --> suitcase
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.8ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 1 book, 37.7ms
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.31
# Class name --> suitcase
# Speed: 0.6ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 suitcases, 1 book, 36.5ms
# Confidence ---> 0.4
# Class name --> suitcase
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.3
# Class name --> suitcase
# Speed: 0.8ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 50.3ms
# Confidence ---> 0.31
# Class name --> cup
# Speed: 0.7ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 book, 39.3ms
# Confidence ---> 0.28
# Class name --> cup
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 39.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 book, 43.7ms
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 43.8ms
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.4ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.9ms
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.7ms
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.6ms preprocess, 37.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 39.0ms
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.6ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.4ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.8ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 43.4ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.9ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.6ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.9ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.5ms
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.7ms
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.1ms
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 39.0ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 47.5ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.6ms
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.8ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 39.7ms
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.6ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 37.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.6ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.0ms
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.6ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.2ms
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.6ms preprocess, 38.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 43.7ms
# Confidence ---> 0.35
# Class name --> book
# Speed: 0.8ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.6ms
# Confidence ---> 0.36
# Class name --> book
# Speed: 0.7ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.9ms
# Confidence ---> 0.37
# Class name --> book
# Speed: 0.6ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 39.5ms
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.6ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.4ms
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.8ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.9ms
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.7ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 43.1ms
# Confidence ---> 0.37
# Class name --> book
# Speed: 0.6ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 64.5ms
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.8ms preprocess, 64.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 40.3ms
# Confidence ---> 0.35
# Class name --> book
# Speed: 0.6ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 39.4ms
# Confidence ---> 0.35
# Class name --> book
# Speed: 0.6ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 41.8ms
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.6ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.8ms
# Speed: 0.6ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 38.0ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 0.7ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 0.6ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.8ms
# Speed: 0.8ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.3ms
# Speed: 0.6ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 0.7ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 1 book, 39.6ms
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> book
# Speed: 0.7ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 48.2ms
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.8ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 37.9ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.9ms
# Speed: 0.6ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 37.7ms
# Confidence ---> 0.3
# Class name --> cup
# Speed: 0.8ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 handbag, 1 cup, 41.9ms
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.27
# Class name --> handbag
# Speed: 0.8ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 books, 54.0ms
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 54.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 0.6ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.4ms
# Speed: 0.7ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.7ms
# Speed: 0.6ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.6ms
# Speed: 0.6ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.0ms
# Speed: 0.7ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 40.7ms
# Confidence ---> 0.43
# Class name --> cup
# Speed: 0.7ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 0.7ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.7ms
# Speed: 0.7ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 41.0ms
# Confidence ---> 0.27
# Class name --> cup
# Speed: 0.7ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.9ms
# Speed: 0.8ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.1ms
# Speed: 0.9ms preprocess, 45.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.2ms
# Speed: 0.8ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 40.7ms
# Confidence ---> 0.32
# Class name --> suitcase
# Speed: 0.7ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.8ms
# Speed: 0.7ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.2ms
# Speed: 0.7ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 0.7ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 0.6ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.2ms
# Speed: 0.6ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.0ms
# Speed: 0.9ms preprocess, 59.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 0.6ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 0.6ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 0.6ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.3ms
# Speed: 0.7ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.3ms
# Speed: 0.6ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 43.1ms
# Confidence ---> 0.27
# Class name --> suitcase
# Speed: 0.8ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 suitcases, 2 books, 45.1ms
# Confidence ---> 0.34
# Class name --> suitcase
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> suitcase
# Speed: 0.6ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 2 books, 43.0ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.29
# Class name --> suitcase
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.9ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 books, 44.2ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 40.6ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.28
# Class name --> toothbrush
# Speed: 0.6ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.9ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 52.6ms
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.9ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 40.3ms
# Confidence ---> 0.39
# Class name --> cup
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.7ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 40.4ms
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> cup
# Speed: 0.8ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.7ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 42.9ms
# Confidence ---> 0.71
# Class name --> cup
# Confidence ---> 0.43
# Class name --> person
# Speed: 0.7ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.6ms
# Confidence ---> 0.78
# Class name --> cup
# Confidence ---> 0.48
# Class name --> person
# Speed: 0.6ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 47.6ms
# Confidence ---> 0.72
# Class name --> cup
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.0ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.3ms
# Confidence ---> 0.8
# Class name --> cup
# Confidence ---> 0.6
# Class name --> person
# Speed: 0.6ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 50.5ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Speed: 0.7ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 40.7ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.32
# Class name --> toothbrush
# Speed: 0.6ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 40.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 0.6ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 52.2ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.71
# Class name --> cup
# Speed: 0.7ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.8ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.63
# Class name --> cup
# Speed: 0.6ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.1ms
# Confidence ---> 0.72
# Class name --> cup
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.7ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 48.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.76
# Class name --> cup
# Speed: 0.8ms preprocess, 48.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 40.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 0.6ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 39.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> remote
# Speed: 0.6ms preprocess, 39.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 remote, 42.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.31
# Class name --> remote
# Confidence ---> 0.31
# Class name --> cup
# Speed: 0.6ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.0ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.7ms preprocess, 39.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.6ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.4ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.6ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.6ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 38.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 0.6ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 39.9ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 0.6ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.49
# Class name --> remote
# Speed: 0.7ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 50.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.33
# Class name --> remote
# Speed: 1.1ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.0ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 0.9ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 39.4ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 0.9ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 40.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 0.6ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.0ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.36
# Class name --> remote
# Speed: 0.7ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.7ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.6ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 42.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.32
# Class name --> remote
# Speed: 0.6ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.6ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.8ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.7ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.6ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.6ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Speed: 0.9ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.28
# Class name --> cup
# Speed: 0.6ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.6ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.6ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.6ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 42.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 0.8ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.69
# Class name --> cup
# Speed: 0.6ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 60.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Speed: 0.7ms preprocess, 60.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 45.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Speed: 0.7ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 43.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.32
# Class name --> cup
# Speed: 0.7ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 39.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Speed: 0.6ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Speed: 0.6ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 48.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.37
# Class name --> cup
# Speed: 0.6ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 40.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 0.6ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 77.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 0.7ms preprocess, 77.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 57.8ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Speed: 0.9ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 42.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Speed: 0.7ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 43.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Speed: 0.7ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 38.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Speed: 0.7ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 44.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Speed: 0.6ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Speed: 0.7ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 38.7ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Speed: 0.7ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 41.0ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Speed: 0.6ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 175.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 18.6ms preprocess, 175.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 48.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.8ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 42.9ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 44.4ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.5
# Class name --> person
# Speed: 0.8ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 52.4ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.49
# Class name --> person
# Speed: 0.8ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 46.1ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.49
# Class name --> person
# Speed: 1.2ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 47.3ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.7ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 47.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.7ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 46.4ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.8ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.7ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 43.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.63
# Class name --> cup
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.6ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 44.8ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.66
# Class name --> cup
# Confidence ---> 0.49
# Class name --> person
# Speed: 0.8ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.2ms
# Confidence ---> 0.64
# Class name --> cup
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.7ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 42.7ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.6
# Class name --> cup
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.7ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 42.5ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.6ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 46.3ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.7ms preprocess, 46.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 43.6ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.6ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.6ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Speed: 0.7ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 43.8ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.56
# Class name --> person
# Speed: 0.8ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 46.8ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 0.7ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.8ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.56
# Class name --> person
# Speed: 0.6ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 44.0ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.56
# Class name --> person
# Speed: 0.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 48.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 0.8ms preprocess, 48.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.6ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 39.9ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 0.9ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 39.7ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 0.6ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 46.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 0.6ms preprocess, 46.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 40.9ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 0.6ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 43.3ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 0.8ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 41.4ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 0.6ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 44.2ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Speed: 0.8ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 39.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Speed: 0.8ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 43.2ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 0.7ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 40.8ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 0.7ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 44.6ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 46.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 42.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 2 books, 40.7ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> suitcase
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 3 books, 42.7ms
# Confidence ---> 0.41
# Class name --> suitcase
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 0.8ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 42.3ms
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.6ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.6ms
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.9ms preprocess, 52.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.3ms
# Speed: 0.6ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.7ms
# Speed: 0.7ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.2ms
# Speed: 0.7ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 0.7ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.0ms
# Speed: 0.7ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 0.8ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.5ms
# Speed: 0.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.3ms
# Speed: 0.6ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 0.6ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 0.8ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 0.7ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 0.7ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 0.6ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 0.8ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.6ms
# Speed: 0.6ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 0.6ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 0.6ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.8ms
# Speed: 0.6ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.6ms
# Speed: 0.7ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 0.8ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 0.6ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 0.6ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 0.6ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.8ms
# ...
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.7ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 50.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> cell phone
# Speed: 0.7ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 40.9ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.8ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 43.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> cell phone
# Speed: 0.6ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 57.2ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 57.8ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.7ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 41.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.8ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 46.1ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.7ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 book, 60.1ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 60.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 44.6ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 book, 51.4ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.0ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 book, 42.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 1 book, 43.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.62
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.9ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 43.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 0.7ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 44.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Speed: 0.7ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 43.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
# Speed: 0.7ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 42.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 0.7ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 55.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.67
# Class name --> cell phone
# Speed: 1.0ms preprocess, 55.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 44.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> cell phone
# Speed: 0.8ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 44.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Speed: 0.8ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.7ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 42.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 book, 43.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> remote
# Confidence ---> 0.26
# Class name --> book
# Speed: 1.0ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 60.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.78
# Class name --> remote
# Speed: 0.8ms preprocess, 60.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 laptop, 1 book, 56.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> suitcase
# Confidence ---> 0.27
# Class name --> book
# Speed: 0.7ms preprocess, 56.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 2 books, 45.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.36
# Class name --> suitcase
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.7ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 42.1ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.37
# Class name --> suitcase
# Speed: 0.6ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.7ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 0.6ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.5ms
# Speed: 0.8ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.2ms
# Speed: 0.8ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 0.6ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 0.8ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.9ms
# Speed: 0.8ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 0.7ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.0ms
# Speed: 0.8ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.0ms
# Speed: 0.8ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.5ms
# Speed: 0.6ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 0.6ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.6ms
# Speed: 0.6ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.5ms
# Speed: 0.6ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 0.8ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.0ms
# Speed: 0.8ms preprocess, 61.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.9ms
# Speed: 0.7ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 0.6ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 0.6ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.7ms
# Speed: 0.7ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.5ms
# Speed: 0.7ms preprocess, 47.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.7ms
# Speed: 0.7ms preprocess, 60.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 0.6ms preprocess, 52.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.8ms
# Speed: 0.6ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 0.6ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 45.4ms
# Confidence ---> 0.3
# Class name --> book
# Speed: 0.7ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.5ms
# Speed: 0.6ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.0ms
# Speed: 0.7ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 44.3ms
# Confidence ---> 0.29
# Class name --> cup
# Speed: 0.8ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.2ms
# Speed: 0.8ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 0.7ms preprocess, 53.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 50.0ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 55.7ms
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 books, 44.9ms
# Confidence ---> 0.26
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 43.1ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.7ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.6ms
# Speed: 1.5ms preprocess, 75.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 0.8ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 48.9ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.1ms
# Speed: 0.9ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.7ms
# Speed: 0.7ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 53.8ms
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.8ms preprocess, 53.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.3ms
# Speed: 0.7ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.7ms
# Speed: 0.6ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1 book, 46.9ms
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.6ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1 book, 47.3ms
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.8ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 44.4ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Speed: 0.7ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 46.4ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.4ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 42.9ms
# Confidence ---> 0.33
# Class name --> book
# Speed: 0.8ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 66.6ms
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.8ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 47.9ms
# Confidence ---> 0.34
# Class name --> book
# Speed: 0.7ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bed, 2 books, 48.0ms
# Confidence ---> 0.39
# Class name --> bed
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bed, 2 books, 43.8ms
# Confidence ---> 0.51
# Class name --> bed
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.26
# Class name --> book
# Speed: 0.6ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bed, 1 book, 50.5ms
# Confidence ---> 0.52
# Class name --> bed
# Confidence ---> 0.32
# Class name --> book
# Speed: 0.9ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.1: Run YOLO on an Image (the simple way)**

# %%
# Run yolo model on an image
results = model.predict(source="/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/cat.jpg", show=True)
# Out:
# image 1/1 /Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/cat.jpg: 640x640 1 cat, 283.9ms
# Speed: 10.5ms preprocess, 283.9ms inference, 21.1ms postprocess per image at shape (1, 3, 640, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 5.2: Run YOLO on an Image (the complete way)**

# %% [markdown]
# Load your image and prepare it for inference:

# %%
# Load an image (change the path to your image file)
image_bgr = cv2.imread('/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg')

# %% [markdown]
# Run inference

# %%
# Run inference
results = model(image_bgr)
# Out:
# 0: 640x640 1 cat, 194.7ms
# Speed: 35.0ms preprocess, 194.7ms inference, 14.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Extract detection results
boxes = results[0].boxes  # Bounding boxes
scores = boxes.conf       # Confidence scores
class_ids = boxes.cls     # Class IDs

# Create a copy of the original image to draw on
image_with_boxes = image_bgr.copy()

# Define colors for different classes
colors = [(0, 255, 0), (0, 0, 255), (255, 0, 0), (255, 255, 0), 
          (0, 255, 255), (255, 0, 255), (255, 165, 0), (128, 0, 128)]

# Draw bounding boxes and labels for each detection
for i, (box, score, class_id) in enumerate(zip(boxes.xyxy, scores, class_ids)):
    # Convert tensor to numpy array
    x1, y1, x2, y2 = box.cpu().numpy()
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    
    # Get class name and color
    class_name = model.names[class_id]
    color = colors[class_id % len(colors)]
    
    # Draw bounding box
    cv2.rectangle(image_with_boxes, (int(x1), int(y1)), (int(x2), int(y2)), color, 5)
    
    # Create label text
    label = f"{class_name}: {score:.2f}"
    
    # Calculate text position
    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
    label_y = max(int(y1) - 10, label_size[1] + 10)
    
    # Draw text background
    cv2.rectangle(image_with_boxes, 
                 (int(x1), label_y - label_size[1] - 10),
                 (int(x1) + label_size[0], label_y + 5),
                 color, -1)
    
    # Draw text
    cv2.putText(image_with_boxes, label, 
               (int(x1), label_y - 5), 
               cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
# Convert from BGR to RGB for matplotlib
image_with_boxes_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the result
plt.figure(figsize=(12, 10))
plt.imshow(image_with_boxes_rgb)
plt.title('Object Detection with YOLOv11')
plt.axis('off')
plt.show()

# Print detection summary
print(f"Detected {len(boxes)} objects:")
for i, (class_id, score) in enumerate(zip(class_ids, scores)):
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    print(f"  {i+1}. {model.names[class_id]} (confidence: {score:.2f})")

# %% [markdown]
# ### **Step 6.1: Run Object Detection on a saved video (the simple way)**

# %% [markdown]
# Inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos.

# %%
# YOLO on a saved video
results = model.predict(source='/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/car-detection.mp4', show=True, stream=True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### **Step 6.2: Run Object Detection on a saved video (the complete way)**

# %%
# Load YOLO model
model = YOLO('yolov8n.pt')

# Configure your video path
video_path = "/Users/eugenio/Documents/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/race_car.mp4"

# Open video
cap = cv2.VideoCapture(video_path)

# Verify video opened correctly
if not cap.isOpened():
    print("Error: Could not open video. Check the path.")
else:
    print("Video loaded successfully. Press 'q' to exit.")
    
    # Process each video frame
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break  # Finish when video ends
            
        # Run detection with YOLO
        results = model(frame)
        
        # Draw bounding boxes
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                confidence = float(box.conf[0].cpu().numpy())
                class_id = int(box.cls[0].cpu().numpy())
                
                # Only show detections with confidence > 50%
                if confidence > 0.5:
                    # Draw rectangle
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Show label
                    label = f"{model.names[class_id]}: {confidence:.2f}"
                    cv2.putText(frame, label, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Show frame with detections
        cv2.imshow('Object Detection', frame)
        
        # Exit with 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Processing completed.")
# Out:
# Video loaded successfully. Press 'q' to exit.
#
# 0: 416x640 2 cars, 182.5ms
# Speed: 5.0ms preprocess, 182.5ms inference, 5.6ms postprocess per image at shape (1, 3, 416, 640)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 416x640 2 cars, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.3ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 62.5ms
# Speed: 1.1ms preprocess, 62.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 1.2ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 7.9ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.2ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.2ms
# Speed: 1.1ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.9ms
# Speed: 1.1ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.0ms
# Speed: 0.9ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.1ms
# Speed: 1.2ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.1ms
# Speed: 1.1ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 0.9ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.8ms
# Speed: 1.1ms preprocess, 34.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.2ms
# Speed: 9.1ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 0.9ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.9ms
# Speed: 0.9ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 persons, 2 cars, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 3 cars, 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 34.3ms
# Speed: 1.1ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.8ms
# Speed: 0.9ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.5ms
# Speed: 1.0ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.8ms
# Speed: 0.9ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.7ms
# Speed: 0.9ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 35.0ms
# Speed: 1.2ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 2 cars, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 cars, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.8ms
# Speed: 0.9ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 31.4ms
# Speed: 1.0ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 6.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.4ms
# Speed: 6.2ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 0.9ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 0.9ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.2ms
# Speed: 1.0ms preprocess, 30.2ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 0.9ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 0.9ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.9ms
# Speed: 1.1ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.2ms
# Speed: 0.9ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.7ms
# Speed: 1.2ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.5ms
# Speed: 1.1ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.7ms
# Speed: 1.1ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.3ms
# Speed: 0.9ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 79.0ms
# Speed: 1.0ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 1 motorcycle, 35.1ms
# Speed: 1.1ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 33.3ms
# Speed: 1.2ms preprocess, 33.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.8ms
# Speed: 1.0ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 31.9ms
# Speed: 0.9ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.9ms
# Speed: 1.0ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 cars, 30.3ms
# Speed: 1.0ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
# Processing completed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## **Activity**
#
# ### **Option 1: Mathematics Track**
#
# Clone your repository from GitHub and run the system directly on the Jetson Nano.
#
# #### Access to the Jetson Nano
#
# You will be provided with:
# - Username
# - Jetson Nano IP address
# - Password
#
# Use your computer's terminal to connect:
#
# `ssh username@jetson_ip`
#
# #### 1. Clone the repository
# `git clone https://github.com/user/repository.git`
#
# #### 2. Access the project directory
# `cd repository`
#
# #### 3. Create virtual environment and install dependencies
# `python3 -m venv env`
# `source env/bin/activate`
# `pip install -r requirements.txt`
#
# #### 4. Run the virtual environment
# `python YOLO-Real-Time.py`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. SSH Connection** | 2 | Successfully establishes SSH connection to Jetson Nano. Properly handles authentication and connection setup. |
# | **2. Environment Setup** | 3 | Creates virtual environment and installs all dependencies correctly. Resolves any platform-specific issues. |
# | **3. Application Execution** | 3 | Runs YOLO real-time detection successfully on Jetson Nano. Handles hardware acceleration properly. |
# | **4. Performance Optimization** | 2 | Implements optimizations for Jetson Nano hardware. Maintains acceptable frame rate for real-time detection. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 2: Computer Science Track**
#
# Create a Dockerfile in your Jetson Nano folder:
#
# #### Dockerfile
#
# `FROM nvcr.io/nvidia/l4t-pytorch:r32.7.1-pth1.11-py3`
# `RUN apt-get update && apt-get install -y python3-pip libopencv-dev`
# `RUN pip3 install ultralytics opencv-python`
#
# `COPY . /app`
# `WORKDIR /app`
#
# `CMD ["python3", "YOLO-Real-Time.py"]`
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### Steps to build and run:
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Repository Setup** | 2 | Successfully clones repository and sets up environment. All dependencies installed correctly without errors. |
# | **2. Docker Implementation** | 3 | Dockerfile is properly configured with all necessary dependencies. Image builds successfully without errors. |
# | **3. Container Execution** | 3 | Container runs successfully with camera access. Real-time detection works properly in Docker environment. |
# | **4. System Performance** | 2 | Application runs smoothly with acceptable frame rate. Handles video streaming without crashes or major issues. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 3: Master's in Artificial Intelligence / Data Science**
#
# In this option, the work will be developed **locally on your personal computers**.
#
# #### Objective
# Design a **specific object detection application** using YOLO (You Only Look Once), focused on **a limited subset of classes**. The system must show that **it only detects the activated classes**, visually ignoring objects belonging to deactivated classes (even if they are present in the image).
#
# #### Instructions
#
# 1. **Define a concrete application and the problem it solves**, for example: vehicle detection, fruits detection, etc.
# 2. **Select between 2 and 4 classes** from the YOLOv8 model to detect.
# 3. **Modify the model logic** or post-processing so that **only the selected classes are shown**.
# 4. Run the application on video where **objects from non-activated classes** are also present to demonstrate that the system **ignores those classes**.
# 5. Show the results clearly, visually indicating the detected and non-detected objects.
#
# #### Technical Requirements
#
# - Use `ultralytics` with `YOLO` in any version.
# - You can use your webcam video or local video (no static images allowed).
#
# #### Deliverable
#
# Must be uploaded to the virtual classroom:
#
# - **Jupyter Notebook in PDF format** containing:
# - Commented code
# - Application title and the problem it solves
# - List of activated classes
# - Screenshots or test images with results showing:
#   - Objects *correctly detected* according to the activated classes.
#   - Objects *not detected* because they belong to deactivated classes (even if present in the image).
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Application Definition and Problem Statement** | 1 | Clearly defines a specific object detection application and its practical use case. Selects appropriate classes for the application context. |
# | **2. Class Selection and Justification** | 1 | Selects between 2-4 relevant classes from YOLOv8 model. Demonstrates thoughtful choice of classes for the specific application. |
# | **3. Implementation** | 4 | Successfully modifies the model logic or post-processing to only show selected classes. Code is functional and properly ignores non-selected classes. |
# | **4. Testing & Evidence** | 3 | Provides a clear test showing both detected (activated classes) and ignored (deactivated classes) objects. Evidence demonstrates the filtering works correctly. |
# | **5. Documentation** | 1 | Delivers complete documentation including PDF notebook, application title, class list, and proper screenshots. Submission is well-organized and professional. |
#
# Total: 10 points

# %%
# Write your code here..

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
