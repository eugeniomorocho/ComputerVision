# %%
# Import the video classroom.mp4 with OpenCV and display it in a window. Press 'q' to exit the video.
import cv2
cap = cv2.VideoCapture('classroom.mp4')

# %%
# Print the fps of the video
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"FPS: {fps}")
# Out:
# FPS: 30.0
